# %% [markdown]
# apa yang dimaksud persamaan linier
#
#
#
# gambarnya pakai geo gebra
#
# ```
# # Ini diformat sebagai kode
# ```

# %% [markdown]
# Persamaan linear adalah persamaan aljabar yang memiliki dua karakteristik utama:Variabel berpangkat satu: Tidak ada variabel kuadrat ($x^2$) atau pangkat lebih tinggi.Grafik garis lurus: Jika digambar pada koordinat Kartesius, hasilnya tidak melengkung.Bentuk Umum (Dua Variabel)$$ax + by = c$$Contoh Sederhana$$2x + y = 5$$
#
# persamaan linear $$x + y = 5$$ dan $$2x - y = 4$$
# ![Screenshot 2026-02-12 210525.png](data:image/png;base64,...)
